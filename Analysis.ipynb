# %%
import numpy as np
import pandas as pd
import seaborn

# %%
filename = 'NCAA_data.csv'

data = pd.read_csv(filename)

# %%
print(data.head)
# Out:
# <bound method NDFrame.head of    Unnamed: 0             Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0          Rk                 School        Conf         NaN          W
# 1           1                Gonzaga         WCC         NaN         33
# 2           2                   Duke         ACC         NaN         32
# 3           3               Virginia         ACC         NaN         34
# 4           4         Michigan State     Big Ten         NaN         32
# 5           5         North Carolina         ACC         NaN         29
# 6           6             Texas Tech      Big 12         NaN         31
# 7           7               Michigan     Big Ten         NaN         30
# 8           8              Tennessee         SEC         NaN         31
# 9           9               Kentucky         SEC         NaN         30
# 10         10                 Purdue     Big Ten         NaN         26
# 11         11                 Auburn         SEC         NaN         30
# ...
